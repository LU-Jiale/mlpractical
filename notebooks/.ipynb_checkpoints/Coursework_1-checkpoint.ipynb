# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework1.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    fig_1.tight_layout() # This minimises whitespace around the axes.
    fig_1.savefig('error.svg') # Save figure to current directory in PDF format
    fig_2.tight_layout() # This minimises whitespace around the axes.
    fig_2.savefig('acc.svg') # Save figure to current directory in PDF format
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %% [markdown]
# # Batch size = 50

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider

# Seed a random number generator
seed = 10102016 
rng = np.random.RandomState(seed)
batch_size = 50
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = MNISTDataProvider('valid', batch_size=batch_size, rng=rng)

# %% [markdown]
# # RELU activation function

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 1.8s to complete
#     error(train)=1.82e-01, acc(train)=9.46e-01, error(valid)=1.78e-01, acc(valid)=9.50e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 2.1s to complete
#     error(train)=1.16e-01, acc(train)=9.66e-01, error(valid)=1.22e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 1.7s to complete
#     error(train)=9.29e-02, acc(train)=9.72e-01, error(valid)=1.11e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 1.6s to complete
#     error(train)=8.39e-02, acc(train)=9.74e-01, error(valid)=1.08e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 2.1s to complete
#     error(train)=6.02e-02, acc(train)=9.82e-01, error(valid)=9.23e-02, acc(valid)=9.70e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 2.6s to complete
#     error(train)=4.39e-02, acc(train)=9.87e-01, error(valid)=8.67e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 2.4s to complete
#     error(train)=3.73e-02, acc(train)=9.89e-01, error(valid)=8.13e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 1.8s to complete
#     error(train)=3.46e-02, acc(train)=9.90e-01, error(valid)=8.54e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 2.3s to complete
#     error(train)=2.56e-02, acc(train)=9.93e-01, error(valid)=7.92e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 2.1s to complete
#     error(train)=2.16e-02, acc(train)=9.94e-01, error(valid)=7.88e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 2.3s to complete
#     error(train)=1.82e-02, acc(train)=9.95e-01, error(valid)=8.02e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 1.7s to complete
#     error(train)=1.48e-02, acc(train)=9.97e-01, error(valid)=7.93e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 1.7s to complete
#     error(train)=1.28e-02, acc(train)=9.97e-01, error(valid)=7.87e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 1.8s to complete
#     error(train)=1.10e-02, acc(train)=9.97e-01, error(valid)=8.38e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 2.1s to complete
#     error(train)=8.77e-03, acc(train)=9.98e-01, error(valid)=8.62e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 1.9s to complete
#     error(train)=8.09e-03, acc(train)=9.98e-01, error(valid)=8.87e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 2.3s to complete
#     error(train)=9.13e-03, acc(train)=9.98e-01, error(valid)=9.00e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 2.5s to complete
#     error(train)=5.30e-03, acc(train)=9.99e-01, error(valid)=8.57e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 1.7s to complete
#     error(train)=3.92e-03, acc(train)=1.00e+00, error(valid)=8.83e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 2.2s to complete
#     error(train)=3.14e-03, acc(train)=1.00e+00, error(valid)=8.96e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 1.8s to complete
#     error(train)=2.14e-03, acc(train)=1.00e+00, error(valid)=8.57e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 1.9s to complete
#     error(train)=2.05e-03, acc(train)=1.00e+00, error(valid)=8.68e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 2.3s to complete
#     error(train)=1.85e-03, acc(train)=1.00e+00, error(valid)=8.95e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 1.7s to complete
#     error(train)=1.55e-03, acc(train)=1.00e+00, error(valid)=9.15e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 1.7s to complete
#     error(train)=1.38e-03, acc(train)=1.00e+00, error(valid)=9.28e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 1.9s to complete
#     error(train)=1.51e-03, acc(train)=1.00e+00, error(valid)=9.32e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 2.8s to complete
#     error(train)=1.18e-03, acc(train)=1.00e+00, error(valid)=9.38e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 1.9s to complete
#     error(train)=1.08e-03, acc(train)=1.00e+00, error(valid)=9.52e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 2.5s to complete
#     error(train)=9.91e-04, acc(train)=1.00e+00, error(valid)=9.60e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 1.9s to complete
#     error(train)=9.58e-04, acc(train)=1.00e+00, error(valid)=9.48e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 3.2s to complete
#     error(train)=8.45e-04, acc(train)=1.00e+00, error(valid)=9.56e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 2.1s to complete
#     error(train)=8.27e-04, acc(train)=1.00e+00, error(valid)=9.71e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 2.4s to complete
#     error(train)=7.80e-04, acc(train)=1.00e+00, error(valid)=9.77e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 1.6s to complete
#     error(train)=7.25e-04, acc(train)=1.00e+00, error(valid)=9.79e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 2.8s to complete
#     error(train)=6.90e-04, acc(train)=1.00e+00, error(valid)=9.83e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 2.8s to complete
#     error(train)=6.57e-04, acc(train)=1.00e+00, error(valid)=9.96e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 2.9s to complete
#     error(train)=6.18e-04, acc(train)=1.00e+00, error(valid)=9.94e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 2.0s to complete
#     error(train)=6.15e-04, acc(train)=1.00e+00, error(valid)=9.99e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 2.2s to complete
#     error(train)=5.73e-04, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 1.9s to complete
#     error(train)=5.59e-04, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 3.0s to complete
#     error(train)=5.53e-04, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 1.9s to complete
#     error(train)=5.13e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 2.7s to complete
#     error(train)=4.92e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 2.4s to complete
#     error(train)=4.86e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 2.1s to complete
#     error(train)=4.78e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 2.1s to complete
#     error(train)=4.43e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 2.0s to complete
#     error(train)=4.29e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 1.9s to complete
#     error(train)=4.18e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 1.9s to complete
#     error(train)=3.99e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 1.9s to complete
#     error(train)=3.94e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 2.4s to complete
#     error(train)=3.80e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 2.0s to complete
#     error(train)=3.68e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 2.0s to complete
#     error(train)=3.66e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 1.9s to complete
#     error(train)=3.54e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 2.2s to complete
#     error(train)=3.40e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 2.5s to complete
#     error(train)=3.33e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 2.3s to complete
#     error(train)=3.23e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 2.1s to complete
#     error(train)=3.15e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 2.1s to complete
#     error(train)=3.06e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 1.8s to complete
#     error(train)=2.98e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 1.7s to complete
#     error(train)=2.93e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 1.6s to complete
#     error(train)=2.84e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 1.6s to complete
#     error(train)=2.78e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 1.9s to complete
#     error(train)=2.73e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 2.1s to complete
#     error(train)=2.69e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 2.5s to complete
#     error(train)=2.61e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 2.3s to complete
#     error(train)=2.54e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 2.3s to complete
#     error(train)=2.51e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 1.9s to complete
#     error(train)=2.44e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 1.6s to complete
#     error(train)=2.42e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 2.2s to complete
#     error(train)=2.34e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 2.1s to complete
#     error(train)=2.32e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 3.2s to complete
#     error(train)=2.29e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 2.0s to complete
#     error(train)=2.23e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 2.2s to complete
#     error(train)=2.17e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 2.2s to complete
#     error(train)=2.17e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 2.3s to complete
#     error(train)=2.10e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 2.0s to complete
#     error(train)=2.08e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 1.6s to complete
#     error(train)=2.03e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 2.2s to complete
#     error(train)=1.99e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 1.9s to complete
#     error(train)=1.96e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 2.4s to complete
#     error(train)=1.94e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 2.1s to complete
#     error(train)=1.91e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 1.7s to complete
#     error(train)=1.88e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 1.7s to complete
#     error(train)=1.84e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 2.4s to complete
#     error(train)=1.81e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 1.5s to complete
#     error(train)=1.78e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 1.8s to complete
#     error(train)=1.77e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 1.7s to complete
#     error(train)=1.73e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 1.6s to complete
#     error(train)=1.70e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 2.0s to complete
#     error(train)=1.69e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 1.8s to complete
#     error(train)=1.65e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 2.1s to complete
#     error(train)=1.62e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 1.9s to complete
#     error(train)=1.61e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 1.8s to complete
#     error(train)=1.58e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 1.7s to complete
#     error(train)=1.56e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 1.9s to complete
#     error(train)=1.54e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 1.8s to complete
#     error(train)=1.52e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 1.7s to complete
#     error(train)=1.49e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 1.7s to complete
#     error(train)=1.47e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00

# %% [markdown]
# # LRELU activation function

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 2.2s to complete
#     error(train)=1.71e-01, acc(train)=9.49e-01, error(valid)=1.66e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 2.1s to complete
#     error(train)=1.10e-01, acc(train)=9.68e-01, error(valid)=1.17e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 2.5s to complete
#     error(train)=8.78e-02, acc(train)=9.75e-01, error(valid)=1.07e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 1.9s to complete
#     error(train)=6.87e-02, acc(train)=9.80e-01, error(valid)=9.70e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 2.0s to complete
#     error(train)=5.06e-02, acc(train)=9.86e-01, error(valid)=8.26e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 2.2s to complete
#     error(train)=4.34e-02, acc(train)=9.88e-01, error(valid)=8.08e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 2.3s to complete
#     error(train)=3.80e-02, acc(train)=9.89e-01, error(valid)=8.03e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 2.8s to complete
#     error(train)=3.20e-02, acc(train)=9.91e-01, error(valid)=8.04e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 2.1s to complete
#     error(train)=2.95e-02, acc(train)=9.92e-01, error(valid)=8.35e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 2.0s to complete
#     error(train)=2.09e-02, acc(train)=9.95e-01, error(valid)=7.90e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 2.4s to complete
#     error(train)=1.67e-02, acc(train)=9.96e-01, error(valid)=7.80e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 2.0s to complete
#     error(train)=1.90e-02, acc(train)=9.95e-01, error(valid)=8.48e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 2.2s to complete
#     error(train)=1.34e-02, acc(train)=9.97e-01, error(valid)=8.17e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 1.6s to complete
#     error(train)=1.29e-02, acc(train)=9.97e-01, error(valid)=8.42e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 2.0s to complete
#     error(train)=6.81e-03, acc(train)=9.99e-01, error(valid)=7.78e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 1.8s to complete
#     error(train)=8.71e-03, acc(train)=9.98e-01, error(valid)=8.43e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 1.8s to complete
#     error(train)=6.68e-03, acc(train)=9.99e-01, error(valid)=8.95e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 2.0s to complete
#     error(train)=5.20e-03, acc(train)=9.99e-01, error(valid)=8.27e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 1.6s to complete
#     error(train)=3.59e-03, acc(train)=1.00e+00, error(valid)=8.35e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 1.9s to complete
#     error(train)=2.55e-03, acc(train)=1.00e+00, error(valid)=8.39e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 1.8s to complete
#     error(train)=4.12e-03, acc(train)=1.00e+00, error(valid)=8.73e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 1.8s to complete
#     error(train)=1.90e-03, acc(train)=1.00e+00, error(valid)=8.63e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 2.3s to complete
#     error(train)=1.83e-03, acc(train)=1.00e+00, error(valid)=8.71e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 2.2s to complete
#     error(train)=1.42e-03, acc(train)=1.00e+00, error(valid)=8.81e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 2.3s to complete
#     error(train)=1.32e-03, acc(train)=1.00e+00, error(valid)=8.78e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 1.8s to complete
#     error(train)=1.22e-03, acc(train)=1.00e+00, error(valid)=8.91e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 2.2s to complete
#     error(train)=1.14e-03, acc(train)=1.00e+00, error(valid)=9.06e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 2.1s to complete
#     error(train)=1.03e-03, acc(train)=1.00e+00, error(valid)=9.01e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 2.1s to complete
#     error(train)=1.07e-03, acc(train)=1.00e+00, error(valid)=9.14e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 1.9s to complete
#     error(train)=9.07e-04, acc(train)=1.00e+00, error(valid)=9.19e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 3.2s to complete
#     error(train)=8.44e-04, acc(train)=1.00e+00, error(valid)=9.27e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 1.7s to complete
#     error(train)=8.36e-04, acc(train)=1.00e+00, error(valid)=9.31e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 2.5s to complete
#     error(train)=7.68e-04, acc(train)=1.00e+00, error(valid)=9.47e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 2.2s to complete
#     error(train)=7.30e-04, acc(train)=1.00e+00, error(valid)=9.41e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 1.9s to complete
#     error(train)=6.98e-04, acc(train)=1.00e+00, error(valid)=9.46e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 1.9s to complete
#     error(train)=6.54e-04, acc(train)=1.00e+00, error(valid)=9.57e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 1.9s to complete
#     error(train)=6.32e-04, acc(train)=1.00e+00, error(valid)=9.64e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 2.2s to complete
#     error(train)=5.93e-04, acc(train)=1.00e+00, error(valid)=9.58e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 1.6s to complete
#     error(train)=5.79e-04, acc(train)=1.00e+00, error(valid)=9.69e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 2.1s to complete
#     error(train)=5.46e-04, acc(train)=1.00e+00, error(valid)=9.68e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 1.9s to complete
#     error(train)=5.24e-04, acc(train)=1.00e+00, error(valid)=9.78e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 2.0s to complete
#     error(train)=5.31e-04, acc(train)=1.00e+00, error(valid)=9.78e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 2.1s to complete
#     error(train)=4.88e-04, acc(train)=1.00e+00, error(valid)=9.85e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 1.9s to complete
#     error(train)=4.73e-04, acc(train)=1.00e+00, error(valid)=9.90e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 2.5s to complete
#     error(train)=4.58e-04, acc(train)=1.00e+00, error(valid)=9.93e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 1.9s to complete
#     error(train)=4.44e-04, acc(train)=1.00e+00, error(valid)=9.97e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 2.1s to complete
#     error(train)=4.35e-04, acc(train)=1.00e+00, error(valid)=9.96e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 2.2s to complete
#     error(train)=4.16e-04, acc(train)=1.00e+00, error(valid)=9.99e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 2.1s to complete
#     error(train)=4.01e-04, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 1.9s to complete
#     error(train)=3.91e-04, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 1.7s to complete
#     error(train)=3.82e-04, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 1.9s to complete
#     error(train)=3.68e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 2.4s to complete
#     error(train)=3.65e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 1.6s to complete
#     error(train)=3.50e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 2.1s to complete
#     error(train)=3.39e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 2.2s to complete
#     error(train)=3.30e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 1.8s to complete
#     error(train)=3.21e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 1.9s to complete
#     error(train)=3.11e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 2.3s to complete
#     error(train)=3.07e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 2.0s to complete
#     error(train)=2.98e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 1.9s to complete
#     error(train)=2.89e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 1.8s to complete
#     error(train)=2.86e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 2.0s to complete
#     error(train)=2.83e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 2.1s to complete
#     error(train)=2.73e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 2.3s to complete
#     error(train)=2.67e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 1.8s to complete
#     error(train)=2.62e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 2.4s to complete
#     error(train)=2.54e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 2.3s to complete
#     error(train)=2.49e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 2.5s to complete
#     error(train)=2.46e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 2.0s to complete
#     error(train)=2.42e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 2.2s to complete
#     error(train)=2.37e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 2.3s to complete
#     error(train)=2.33e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 1.9s to complete
#     error(train)=2.27e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 1.9s to complete
#     error(train)=2.24e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 2.4s to complete
#     error(train)=2.19e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 2.5s to complete
#     error(train)=2.14e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 2.8s to complete
#     error(train)=2.10e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 2.3s to complete
#     error(train)=2.07e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 2.4s to complete
#     error(train)=2.04e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 2.0s to complete
#     error(train)=2.01e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 2.2s to complete
#     error(train)=1.97e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 1.7s to complete
#     error(train)=1.93e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 2.4s to complete
#     error(train)=1.90e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 1.9s to complete
#     error(train)=1.87e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 2.0s to complete
#     error(train)=1.84e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 2.5s to complete
#     error(train)=1.81e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 2.0s to complete
#     error(train)=1.78e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 1.9s to complete
#     error(train)=1.76e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 1.7s to complete
#     error(train)=1.73e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 1.9s to complete
#     error(train)=1.72e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 1.7s to complete
#     error(train)=1.68e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 2.1s to complete
#     error(train)=1.66e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 2.7s to complete
#     error(train)=1.63e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 2.0s to complete
#     error(train)=1.60e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 2.0s to complete
#     error(train)=1.60e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 1.9s to complete
#     error(train)=1.56e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 1.8s to complete
#     error(train)=1.54e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 1.8s to complete
#     error(train)=1.52e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 1.6s to complete
#     error(train)=1.50e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 1.9s to complete
#     error(train)=1.48e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00

# %% [markdown]
# # ELU activation function

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 3.0s to complete
#     error(train)=2.22e-01, acc(train)=9.34e-01, error(valid)=2.11e-01, acc(valid)=9.39e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 3.6s to complete
#     error(train)=1.48e-01, acc(train)=9.56e-01, error(valid)=1.51e-01, acc(valid)=9.56e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 2.4s to complete
#     error(train)=1.14e-01, acc(train)=9.66e-01, error(valid)=1.25e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 2.3s to complete
#     error(train)=8.79e-02, acc(train)=9.74e-01, error(valid)=1.04e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 2.6s to complete
#     error(train)=7.71e-02, acc(train)=9.76e-01, error(valid)=1.02e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 2.5s to complete
#     error(train)=6.10e-02, acc(train)=9.82e-01, error(valid)=8.66e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 2.7s to complete
#     error(train)=5.64e-02, acc(train)=9.83e-01, error(valid)=9.25e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 2.3s to complete
#     error(train)=4.84e-02, acc(train)=9.85e-01, error(valid)=8.68e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 2.5s to complete
#     error(train)=4.63e-02, acc(train)=9.86e-01, error(valid)=8.67e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 2.7s to complete
#     error(train)=3.86e-02, acc(train)=9.88e-01, error(valid)=8.43e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 2.3s to complete
#     error(train)=3.19e-02, acc(train)=9.91e-01, error(valid)=8.18e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 3.1s to complete
#     error(train)=2.98e-02, acc(train)=9.91e-01, error(valid)=8.51e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 2.4s to complete
#     error(train)=2.30e-02, acc(train)=9.94e-01, error(valid)=7.52e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 2.3s to complete
#     error(train)=1.96e-02, acc(train)=9.95e-01, error(valid)=8.00e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 2.4s to complete
#     error(train)=1.68e-02, acc(train)=9.96e-01, error(valid)=7.75e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 2.4s to complete
#     error(train)=1.59e-02, acc(train)=9.96e-01, error(valid)=8.31e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 2.6s to complete
#     error(train)=1.48e-02, acc(train)=9.96e-01, error(valid)=8.55e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 2.5s to complete
#     error(train)=1.44e-02, acc(train)=9.96e-01, error(valid)=8.66e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 2.0s to complete
#     error(train)=8.39e-03, acc(train)=9.99e-01, error(valid)=8.04e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 2.4s to complete
#     error(train)=9.83e-03, acc(train)=9.98e-01, error(valid)=8.45e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 2.1s to complete
#     error(train)=7.75e-03, acc(train)=9.99e-01, error(valid)=8.39e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 2.5s to complete
#     error(train)=5.67e-03, acc(train)=9.99e-01, error(valid)=8.52e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 1.8s to complete
#     error(train)=5.20e-03, acc(train)=9.99e-01, error(valid)=8.45e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 2.6s to complete
#     error(train)=4.71e-03, acc(train)=9.99e-01, error(valid)=9.00e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 2.3s to complete
#     error(train)=4.11e-03, acc(train)=1.00e+00, error(valid)=8.84e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 2.3s to complete
#     error(train)=2.98e-03, acc(train)=1.00e+00, error(valid)=8.81e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 2.5s to complete
#     error(train)=2.60e-03, acc(train)=1.00e+00, error(valid)=8.89e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 2.9s to complete
#     error(train)=2.38e-03, acc(train)=1.00e+00, error(valid)=9.00e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 2.8s to complete
#     error(train)=2.14e-03, acc(train)=1.00e+00, error(valid)=9.21e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 2.0s to complete
#     error(train)=1.85e-03, acc(train)=1.00e+00, error(valid)=9.21e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 2.4s to complete
#     error(train)=1.80e-03, acc(train)=1.00e+00, error(valid)=9.30e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 1.9s to complete
#     error(train)=1.54e-03, acc(train)=1.00e+00, error(valid)=9.44e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 1.9s to complete
#     error(train)=1.41e-03, acc(train)=1.00e+00, error(valid)=9.54e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 2.3s to complete
#     error(train)=1.37e-03, acc(train)=1.00e+00, error(valid)=9.55e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 3.1s to complete
#     error(train)=1.24e-03, acc(train)=1.00e+00, error(valid)=9.65e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 2.5s to complete
#     error(train)=1.16e-03, acc(train)=1.00e+00, error(valid)=9.67e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 2.1s to complete
#     error(train)=1.12e-03, acc(train)=1.00e+00, error(valid)=9.78e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 2.2s to complete
#     error(train)=1.00e-03, acc(train)=1.00e+00, error(valid)=9.81e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 2.8s to complete
#     error(train)=9.62e-04, acc(train)=1.00e+00, error(valid)=9.99e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 2.7s to complete
#     error(train)=9.42e-04, acc(train)=1.00e+00, error(valid)=9.96e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 2.4s to complete
#     error(train)=8.72e-04, acc(train)=1.00e+00, error(valid)=9.94e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 2.5s to complete
#     error(train)=8.41e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 2.5s to complete
#     error(train)=8.00e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 2.2s to complete
#     error(train)=7.57e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 2.8s to complete
#     error(train)=7.12e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 1.9s to complete
#     error(train)=6.84e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 2.1s to complete
#     error(train)=6.65e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 2.3s to complete
#     error(train)=6.40e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 2.2s to complete
#     error(train)=6.09e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 3.7s to complete
#     error(train)=5.91e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 2.6s to complete
#     error(train)=5.73e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 2.3s to complete
#     error(train)=5.57e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 3.1s to complete
#     error(train)=5.39e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 3.2s to complete
#     error(train)=5.22e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 3.5s to complete
#     error(train)=4.98e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 2.8s to complete
#     error(train)=4.85e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 2.8s to complete
#     error(train)=4.71e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 2.2s to complete
#     error(train)=4.84e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 2.9s to complete
#     error(train)=4.57e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 2.3s to complete
#     error(train)=4.31e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 2.1s to complete
#     error(train)=4.22e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 2.5s to complete
#     error(train)=4.16e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 2.5s to complete
#     error(train)=4.12e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 2.1s to complete
#     error(train)=3.91e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 2.4s to complete
#     error(train)=3.77e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 2.4s to complete
#     error(train)=3.75e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 2.2s to complete
#     error(train)=3.63e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 2.6s to complete
#     error(train)=3.56e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 2.5s to complete
#     error(train)=3.51e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 2.9s to complete
#     error(train)=3.42e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 2.8s to complete
#     error(train)=3.38e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 2.8s to complete
#     error(train)=3.26e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 3.2s to complete
#     error(train)=3.18e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 2.9s to complete
#     error(train)=3.09e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 2.4s to complete
#     error(train)=3.02e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 2.2s to complete
#     error(train)=3.00e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 2.7s to complete
#     error(train)=2.94e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 2.5s to complete
#     error(train)=2.88e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 2.8s to complete
#     error(train)=2.83e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 2.5s to complete
#     error(train)=2.76e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 2.5s to complete
#     error(train)=2.74e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 2.4s to complete
#     error(train)=2.68e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 2.2s to complete
#     error(train)=2.62e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 2.6s to complete
#     error(train)=2.55e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 2.2s to complete
#     error(train)=2.51e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 2.1s to complete
#     error(train)=2.48e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 3.1s to complete
#     error(train)=2.43e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 2.0s to complete
#     error(train)=2.40e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 3.4s to complete
#     error(train)=2.35e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 2.3s to complete
#     error(train)=2.30e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 2.5s to complete
#     error(train)=2.29e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 2.2s to complete
#     error(train)=2.25e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 3.7s to complete
#     error(train)=2.20e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 2.7s to complete
#     error(train)=2.17e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 4.1s to complete
#     error(train)=2.13e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 3.0s to complete
#     error(train)=2.12e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 2.9s to complete
#     error(train)=2.09e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 2.3s to complete
#     error(train)=2.05e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 2.4s to complete
#     error(train)=2.02e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 2.2s to complete
#     error(train)=1.97e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00

# %% [markdown]
# # SELU activation function

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 2.6s to complete
#     error(train)=2.22e-01, acc(train)=9.36e-01, error(valid)=2.12e-01, acc(valid)=9.38e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 3.0s to complete
#     error(train)=1.49e-01, acc(train)=9.56e-01, error(valid)=1.53e-01, acc(valid)=9.57e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 2.7s to complete
#     error(train)=1.08e-01, acc(train)=9.68e-01, error(valid)=1.22e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 2.8s to complete
#     error(train)=8.69e-02, acc(train)=9.75e-01, error(valid)=1.09e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 2.0s to complete
#     error(train)=7.30e-02, acc(train)=9.78e-01, error(valid)=1.03e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 2.8s to complete
#     error(train)=5.90e-02, acc(train)=9.82e-01, error(valid)=9.16e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 2.4s to complete
#     error(train)=5.38e-02, acc(train)=9.83e-01, error(valid)=9.49e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 2.6s to complete
#     error(train)=5.89e-02, acc(train)=9.81e-01, error(valid)=1.00e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 2.9s to complete
#     error(train)=3.86e-02, acc(train)=9.89e-01, error(valid)=8.10e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 2.2s to complete
#     error(train)=3.18e-02, acc(train)=9.91e-01, error(valid)=7.98e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 3.3s to complete
#     error(train)=2.96e-02, acc(train)=9.91e-01, error(valid)=8.20e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 2.2s to complete
#     error(train)=2.72e-02, acc(train)=9.92e-01, error(valid)=8.19e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 3.6s to complete
#     error(train)=2.58e-02, acc(train)=9.92e-01, error(valid)=8.86e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 2.8s to complete
#     error(train)=1.87e-02, acc(train)=9.95e-01, error(valid)=8.41e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 2.0s to complete
#     error(train)=1.83e-02, acc(train)=9.95e-01, error(valid)=8.78e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 2.4s to complete
#     error(train)=1.52e-02, acc(train)=9.96e-01, error(valid)=8.74e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 2.8s to complete
#     error(train)=1.13e-02, acc(train)=9.97e-01, error(valid)=8.53e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 2.3s to complete
#     error(train)=1.02e-02, acc(train)=9.98e-01, error(valid)=8.62e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 2.2s to complete
#     error(train)=8.68e-03, acc(train)=9.98e-01, error(valid)=8.66e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 2.9s to complete
#     error(train)=6.43e-03, acc(train)=9.99e-01, error(valid)=8.44e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 2.8s to complete
#     error(train)=7.17e-03, acc(train)=9.99e-01, error(valid)=8.93e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 2.5s to complete
#     error(train)=4.95e-03, acc(train)=9.99e-01, error(valid)=8.96e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 3.3s to complete
#     error(train)=3.92e-03, acc(train)=1.00e+00, error(valid)=8.83e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 3.0s to complete
#     error(train)=3.65e-03, acc(train)=1.00e+00, error(valid)=9.04e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 3.1s to complete
#     error(train)=2.58e-03, acc(train)=1.00e+00, error(valid)=9.13e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 2.8s to complete
#     error(train)=2.40e-03, acc(train)=1.00e+00, error(valid)=9.17e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 2.5s to complete
#     error(train)=1.87e-03, acc(train)=1.00e+00, error(valid)=9.00e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 2.7s to complete
#     error(train)=1.94e-03, acc(train)=1.00e+00, error(valid)=9.20e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 2.3s to complete
#     error(train)=1.84e-03, acc(train)=1.00e+00, error(valid)=9.33e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 2.6s to complete
#     error(train)=1.49e-03, acc(train)=1.00e+00, error(valid)=9.36e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 2.1s to complete
#     error(train)=1.36e-03, acc(train)=1.00e+00, error(valid)=9.39e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 3.5s to complete
#     error(train)=1.33e-03, acc(train)=1.00e+00, error(valid)=9.59e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 3.0s to complete
#     error(train)=1.15e-03, acc(train)=1.00e+00, error(valid)=9.51e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 2.5s to complete
#     error(train)=1.13e-03, acc(train)=1.00e+00, error(valid)=9.66e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 3.2s to complete
#     error(train)=1.14e-03, acc(train)=1.00e+00, error(valid)=9.70e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 2.8s to complete
#     error(train)=9.68e-04, acc(train)=1.00e+00, error(valid)=9.79e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 3.4s to complete
#     error(train)=9.36e-04, acc(train)=1.00e+00, error(valid)=9.89e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 2.5s to complete
#     error(train)=9.08e-04, acc(train)=1.00e+00, error(valid)=9.91e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 3.5s to complete
#     error(train)=8.39e-04, acc(train)=1.00e+00, error(valid)=9.98e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 2.1s to complete
#     error(train)=8.29e-04, acc(train)=1.00e+00, error(valid)=9.96e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 2.3s to complete
#     error(train)=7.69e-04, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 3.0s to complete
#     error(train)=7.48e-04, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 2.6s to complete
#     error(train)=7.17e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 2.3s to complete
#     error(train)=6.73e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 2.5s to complete
#     error(train)=6.64e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 2.5s to complete
#     error(train)=6.39e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 2.3s to complete
#     error(train)=6.25e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 2.4s to complete
#     error(train)=5.85e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 3.2s to complete
#     error(train)=5.69e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 3.0s to complete
#     error(train)=5.50e-04, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 3.0s to complete
#     error(train)=5.44e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 2.9s to complete
#     error(train)=5.18e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 2.2s to complete
#     error(train)=5.08e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 2.9s to complete
#     error(train)=4.86e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 3.5s to complete
#     error(train)=4.69e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 2.4s to complete
#     error(train)=4.60e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 2.5s to complete
#     error(train)=4.48e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 2.1s to complete
#     error(train)=4.39e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 2.1s to complete
#     error(train)=4.23e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 2.3s to complete
#     error(train)=4.12e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 2.9s to complete
#     error(train)=4.06e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 3.5s to complete
#     error(train)=3.97e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 3.1s to complete
#     error(train)=3.83e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 2.4s to complete
#     error(train)=3.76e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 3.4s to complete
#     error(train)=3.72e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 3.9s to complete
#     error(train)=3.55e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 3.7s to complete
#     error(train)=3.51e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 3.8s to complete
#     error(train)=3.41e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 2.6s to complete
#     error(train)=3.36e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 2.7s to complete
#     error(train)=3.31e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 2.7s to complete
#     error(train)=3.21e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 3.3s to complete
#     error(train)=3.16e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 2.5s to complete
#     error(train)=3.08e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 3.1s to complete
#     error(train)=3.03e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 2.9s to complete
#     error(train)=2.96e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 2.4s to complete
#     error(train)=2.91e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 1.9s to complete
#     error(train)=2.87e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 3.5s to complete
#     error(train)=2.83e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 2.7s to complete
#     error(train)=2.76e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 2.9s to complete
#     error(train)=2.74e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 2.5s to complete
#     error(train)=2.69e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 2.4s to complete
#     error(train)=2.62e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 2.3s to complete
#     error(train)=2.57e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 3.6s to complete
#     error(train)=2.53e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 3.1s to complete
#     error(train)=2.49e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 2.5s to complete
#     error(train)=2.45e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 3.3s to complete
#     error(train)=2.41e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 2.3s to complete
#     error(train)=2.37e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 2.2s to complete
#     error(train)=2.33e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 2.7s to complete
#     error(train)=2.29e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 3.0s to complete
#     error(train)=2.26e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 2.7s to complete
#     error(train)=2.23e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 3.1s to complete
#     error(train)=2.21e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 3.1s to complete
#     error(train)=2.16e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 3.7s to complete
#     error(train)=2.13e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 3.8s to complete
#     error(train)=2.11e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 3.8s to complete
#     error(train)=2.06e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 2.5s to complete
#     error(train)=2.04e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 2.9s to complete
#     error(train)=2.02e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 2.5s to complete
#     error(train)=2.00e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00

# %% [markdown]
# # Sigmoid activation function

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 3.0s to complete
#     error(train)=5.54e-01, acc(train)=8.56e-01, error(valid)=5.18e-01, acc(valid)=8.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 2.5s to complete
#     error(train)=3.67e-01, acc(train)=8.98e-01, error(valid)=3.39e-01, acc(valid)=9.06e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 1.9s to complete
#     error(train)=3.19e-01, acc(train)=9.09e-01, error(valid)=2.94e-01, acc(valid)=9.17e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 1.7s to complete
#     error(train)=2.80e-01, acc(train)=9.18e-01, error(valid)=2.60e-01, acc(valid)=9.24e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 2.3s to complete
#     error(train)=2.52e-01, acc(train)=9.27e-01, error(valid)=2.36e-01, acc(valid)=9.32e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 2.4s to complete
#     error(train)=2.38e-01, acc(train)=9.30e-01, error(valid)=2.23e-01, acc(valid)=9.35e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 1.7s to complete
#     error(train)=2.21e-01, acc(train)=9.35e-01, error(valid)=2.09e-01, acc(valid)=9.41e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 2.4s to complete
#     error(train)=1.98e-01, acc(train)=9.42e-01, error(valid)=1.90e-01, acc(valid)=9.47e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 1.7s to complete
#     error(train)=1.83e-01, acc(train)=9.47e-01, error(valid)=1.77e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 2.1s to complete
#     error(train)=1.70e-01, acc(train)=9.50e-01, error(valid)=1.68e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 2.2s to complete
#     error(train)=1.61e-01, acc(train)=9.52e-01, error(valid)=1.61e-01, acc(valid)=9.53e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 1.9s to complete
#     error(train)=1.49e-01, acc(train)=9.56e-01, error(valid)=1.52e-01, acc(valid)=9.57e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 1.8s to complete
#     error(train)=1.38e-01, acc(train)=9.60e-01, error(valid)=1.43e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 2.2s to complete
#     error(train)=1.33e-01, acc(train)=9.61e-01, error(valid)=1.38e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 2.0s to complete
#     error(train)=1.23e-01, acc(train)=9.64e-01, error(valid)=1.32e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 2.6s to complete
#     error(train)=1.15e-01, acc(train)=9.67e-01, error(valid)=1.27e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 2.1s to complete
#     error(train)=1.10e-01, acc(train)=9.68e-01, error(valid)=1.24e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 1.8s to complete
#     error(train)=1.05e-01, acc(train)=9.69e-01, error(valid)=1.20e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 2.5s to complete
#     error(train)=9.82e-02, acc(train)=9.72e-01, error(valid)=1.14e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 2.1s to complete
#     error(train)=9.19e-02, acc(train)=9.73e-01, error(valid)=1.11e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 2.1s to complete
#     error(train)=8.74e-02, acc(train)=9.75e-01, error(valid)=1.08e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 2.2s to complete
#     error(train)=8.61e-02, acc(train)=9.75e-01, error(valid)=1.07e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 1.8s to complete
#     error(train)=7.91e-02, acc(train)=9.78e-01, error(valid)=1.03e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 2.1s to complete
#     error(train)=7.76e-02, acc(train)=9.78e-01, error(valid)=1.04e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 3.2s to complete
#     error(train)=7.15e-02, acc(train)=9.80e-01, error(valid)=9.87e-02, acc(valid)=9.70e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 2.9s to complete
#     error(train)=6.81e-02, acc(train)=9.81e-01, error(valid)=9.54e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 2.2s to complete
#     error(train)=6.66e-02, acc(train)=9.82e-01, error(valid)=9.58e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 1.9s to complete
#     error(train)=6.35e-02, acc(train)=9.82e-01, error(valid)=9.49e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 2.1s to complete
#     error(train)=6.19e-02, acc(train)=9.83e-01, error(valid)=9.21e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 1.9s to complete
#     error(train)=5.83e-02, acc(train)=9.84e-01, error(valid)=9.01e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 2.0s to complete
#     error(train)=5.57e-02, acc(train)=9.85e-01, error(valid)=9.04e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 1.9s to complete
#     error(train)=5.20e-02, acc(train)=9.87e-01, error(valid)=8.91e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 1.9s to complete
#     error(train)=5.12e-02, acc(train)=9.86e-01, error(valid)=8.85e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 2.4s to complete
#     error(train)=4.94e-02, acc(train)=9.87e-01, error(valid)=8.73e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 2.3s to complete
#     error(train)=4.61e-02, acc(train)=9.88e-01, error(valid)=8.52e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 2.4s to complete
#     error(train)=4.47e-02, acc(train)=9.88e-01, error(valid)=8.47e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 2.0s to complete
#     error(train)=4.24e-02, acc(train)=9.89e-01, error(valid)=8.43e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 3.3s to complete
#     error(train)=4.15e-02, acc(train)=9.90e-01, error(valid)=8.51e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 2.0s to complete
#     error(train)=3.93e-02, acc(train)=9.91e-01, error(valid)=8.28e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 1.8s to complete
#     error(train)=3.69e-02, acc(train)=9.92e-01, error(valid)=8.18e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 3.4s to complete
#     error(train)=3.57e-02, acc(train)=9.92e-01, error(valid)=8.11e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 2.1s to complete
#     error(train)=3.48e-02, acc(train)=9.92e-01, error(valid)=8.05e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 2.5s to complete
#     error(train)=3.40e-02, acc(train)=9.92e-01, error(valid)=8.27e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 2.3s to complete
#     error(train)=3.20e-02, acc(train)=9.93e-01, error(valid)=7.94e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 2.4s to complete
#     error(train)=3.02e-02, acc(train)=9.94e-01, error(valid)=7.98e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 2.5s to complete
#     error(train)=2.92e-02, acc(train)=9.94e-01, error(valid)=7.89e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 2.2s to complete
#     error(train)=2.89e-02, acc(train)=9.94e-01, error(valid)=8.17e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 2.5s to complete
#     error(train)=2.73e-02, acc(train)=9.95e-01, error(valid)=8.00e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 2.3s to complete
#     error(train)=2.86e-02, acc(train)=9.94e-01, error(valid)=8.30e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 2.2s to complete
#     error(train)=2.68e-02, acc(train)=9.95e-01, error(valid)=8.19e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 2.0s to complete
#     error(train)=2.42e-02, acc(train)=9.95e-01, error(valid)=7.91e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 2.5s to complete
#     error(train)=2.27e-02, acc(train)=9.96e-01, error(valid)=7.86e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 2.1s to complete
#     error(train)=2.21e-02, acc(train)=9.96e-01, error(valid)=7.87e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 2.5s to complete
#     error(train)=2.24e-02, acc(train)=9.96e-01, error(valid)=7.78e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 1.9s to complete
#     error(train)=2.11e-02, acc(train)=9.97e-01, error(valid)=7.95e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 1.6s to complete
#     error(train)=1.96e-02, acc(train)=9.97e-01, error(valid)=7.91e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 2.5s to complete
#     error(train)=1.88e-02, acc(train)=9.97e-01, error(valid)=7.89e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 2.0s to complete
#     error(train)=1.85e-02, acc(train)=9.97e-01, error(valid)=7.95e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 2.4s to complete
#     error(train)=1.80e-02, acc(train)=9.97e-01, error(valid)=7.80e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 2.0s to complete
#     error(train)=1.76e-02, acc(train)=9.97e-01, error(valid)=7.95e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 1.8s to complete
#     error(train)=1.73e-02, acc(train)=9.98e-01, error(valid)=7.81e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 2.1s to complete
#     error(train)=1.68e-02, acc(train)=9.98e-01, error(valid)=7.96e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 1.8s to complete
#     error(train)=1.60e-02, acc(train)=9.98e-01, error(valid)=7.83e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 1.7s to complete
#     error(train)=1.58e-02, acc(train)=9.98e-01, error(valid)=7.90e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 2.1s to complete
#     error(train)=1.49e-02, acc(train)=9.98e-01, error(valid)=7.97e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 1.9s to complete
#     error(train)=1.40e-02, acc(train)=9.98e-01, error(valid)=7.85e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 2.0s to complete
#     error(train)=1.34e-02, acc(train)=9.98e-01, error(valid)=7.89e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 2.6s to complete
#     error(train)=1.30e-02, acc(train)=9.99e-01, error(valid)=7.85e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 2.1s to complete
#     error(train)=1.28e-02, acc(train)=9.99e-01, error(valid)=7.97e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 3.0s to complete
#     error(train)=1.20e-02, acc(train)=9.99e-01, error(valid)=7.99e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 2.3s to complete
#     error(train)=1.18e-02, acc(train)=9.99e-01, error(valid)=7.91e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 2.1s to complete
#     error(train)=1.16e-02, acc(train)=9.99e-01, error(valid)=8.02e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 2.5s to complete
#     error(train)=1.10e-02, acc(train)=9.99e-01, error(valid)=8.02e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 2.8s to complete
#     error(train)=1.07e-02, acc(train)=9.99e-01, error(valid)=8.09e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 2.6s to complete
#     error(train)=1.02e-02, acc(train)=9.99e-01, error(valid)=8.01e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 2.4s to complete
#     error(train)=1.03e-02, acc(train)=9.99e-01, error(valid)=7.97e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 1.5s to complete
#     error(train)=9.76e-03, acc(train)=9.99e-01, error(valid)=8.06e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 1.7s to complete
#     error(train)=9.46e-03, acc(train)=9.99e-01, error(valid)=8.04e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 1.9s to complete
#     error(train)=9.18e-03, acc(train)=9.99e-01, error(valid)=8.08e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 2.0s to complete
#     error(train)=9.24e-03, acc(train)=9.99e-01, error(valid)=8.03e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 2.5s to complete
#     error(train)=8.87e-03, acc(train)=9.99e-01, error(valid)=8.19e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 2.1s to complete
#     error(train)=8.55e-03, acc(train)=9.99e-01, error(valid)=8.09e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 2.3s to complete
#     error(train)=8.16e-03, acc(train)=9.99e-01, error(valid)=8.14e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 2.5s to complete
#     error(train)=8.49e-03, acc(train)=9.99e-01, error(valid)=8.33e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 1.7s to complete
#     error(train)=7.63e-03, acc(train)=9.99e-01, error(valid)=8.13e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 2.3s to complete
#     error(train)=7.70e-03, acc(train)=1.00e+00, error(valid)=8.28e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 1.9s to complete
#     error(train)=7.24e-03, acc(train)=1.00e+00, error(valid)=8.09e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 2.4s to complete
#     error(train)=7.40e-03, acc(train)=1.00e+00, error(valid)=8.30e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 2.4s to complete
#     error(train)=7.08e-03, acc(train)=1.00e+00, error(valid)=8.31e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 2.6s to complete
#     error(train)=6.81e-03, acc(train)=1.00e+00, error(valid)=8.25e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 2.0s to complete
#     error(train)=6.50e-03, acc(train)=1.00e+00, error(valid)=8.26e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 1.8s to complete
#     error(train)=6.63e-03, acc(train)=1.00e+00, error(valid)=8.33e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 1.7s to complete
#     error(train)=6.31e-03, acc(train)=1.00e+00, error(valid)=8.29e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 2.0s to complete
#     error(train)=6.04e-03, acc(train)=1.00e+00, error(valid)=8.29e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 2.0s to complete
#     error(train)=5.87e-03, acc(train)=1.00e+00, error(valid)=8.27e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 2.1s to complete
#     error(train)=5.93e-03, acc(train)=1.00e+00, error(valid)=8.35e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 2.1s to complete
#     error(train)=5.58e-03, acc(train)=1.00e+00, error(valid)=8.38e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 2.0s to complete
#     error(train)=5.69e-03, acc(train)=1.00e+00, error(valid)=8.52e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 1.9s to complete
#     error(train)=5.51e-03, acc(train)=1.00e+00, error(valid)=8.39e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 2.6s to complete
#     error(train)=5.28e-03, acc(train)=1.00e+00, error(valid)=8.36e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00

# %% [markdown]
# # 8 hidden layers using SELU acitivation

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.05
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 8.2s to complete
#     error(train)=1.59e-01, acc(train)=9.52e-01, error(valid)=1.68e-01, acc(valid)=9.50e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-284a199a129c> in <module>()
#      44 #Remember to use notebook=False when you write a script to be run in a terminal
#      45 _ = train_model_and_plot_stats(
# ---> 46     model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
#
# <ipython-input-1-98183f1ad0bb> in train_model_and_plot_stats(model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook)
#      16     # Run the optimiser for 5 epochs (full passes through the training set)
#      17     # printing statistics every epoch.
# ---> 18     stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)
#      19
#      20     # Plot the change in the validation and training set error over training.
#
# ~/mlpractical/mlp/optimisers.py in train(self, num_epochs, stats_interval)
#     142             for epoch in range(1, num_epochs + 1):
#     143                 start_time = time.time()
# --> 144                 self.do_training_epoch()
#     145                 epoch_time = time.time() - start_time
#     146                 if epoch % stats_interval == 0:
#
# ~/mlpractical/mlp/optimisers.py in do_training_epoch(self)
#      66             for inputs_batch, targets_batch in self.train_dataset:
#      67                 activations = self.model.fprop(inputs_batch)
# ---> 68                 grads_wrt_outputs = self.error.grad(activations[-1], targets_batch)
#      69                 grads_wrt_params = self.model.grads_wrt_params(
#      70                     activations, grads_wrt_outputs)
#
# KeyboardInterrupt:

# %% [markdown]
# # 5 hidden layers using SELU acitivation

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.05
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 1: 5.7s to complete
#     error(train)=1.75e-01, acc(train)=9.46e-01, error(valid)=1.78e-01, acc(valid)=9.47e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 2: 5.7s to complete
#     error(train)=1.19e-01, acc(train)=9.63e-01, error(valid)=1.36e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 3: 6.2s to complete
#     error(train)=1.13e-01, acc(train)=9.64e-01, error(valid)=1.32e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 4: 5.7s to complete
#     error(train)=7.77e-02, acc(train)=9.75e-01, error(valid)=1.13e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 5: 7.6s to complete
#     error(train)=5.89e-02, acc(train)=9.82e-01, error(valid)=9.96e-02, acc(valid)=9.70e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 6: 8.0s to complete
#     error(train)=4.57e-02, acc(train)=9.86e-01, error(valid)=9.46e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 7: 7.5s to complete
#     error(train)=4.75e-02, acc(train)=9.84e-01, error(valid)=9.68e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 8: 6.9s to complete
#     error(train)=3.98e-02, acc(train)=9.87e-01, error(valid)=1.00e-01, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 9: 5.7s to complete
#     error(train)=4.05e-02, acc(train)=9.87e-01, error(valid)=9.87e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 10: 5.2s to complete
#     error(train)=2.97e-02, acc(train)=9.90e-01, error(valid)=9.64e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 11: 4.7s to complete
#     error(train)=2.41e-02, acc(train)=9.92e-01, error(valid)=9.62e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 12: 4.6s to complete
#     error(train)=2.24e-02, acc(train)=9.92e-01, error(valid)=9.76e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 13: 6.1s to complete
#     error(train)=1.79e-02, acc(train)=9.94e-01, error(valid)=1.02e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 14: 5.5s to complete
#     error(train)=1.58e-02, acc(train)=9.95e-01, error(valid)=1.02e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 15: 6.4s to complete
#     error(train)=1.58e-02, acc(train)=9.95e-01, error(valid)=1.04e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 16: 4.9s to complete
#     error(train)=1.13e-02, acc(train)=9.97e-01, error(valid)=1.04e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 17: 5.0s to complete
#     error(train)=8.94e-03, acc(train)=9.97e-01, error(valid)=1.02e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 18: 5.3s to complete
#     error(train)=1.12e-02, acc(train)=9.96e-01, error(valid)=1.07e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 19: 4.6s to complete
#     error(train)=1.69e-02, acc(train)=9.94e-01, error(valid)=1.25e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 20: 5.2s to complete
#     error(train)=3.03e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 21: 4.5s to complete
#     error(train)=2.83e-03, acc(train)=9.99e-01, error(valid)=1.04e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 22: 4.8s to complete
#     error(train)=1.18e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 23: 5.1s to complete
#     error(train)=1.09e-03, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 24: 6.0s to complete
#     error(train)=8.40e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 25: 5.4s to complete
#     error(train)=6.41e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 26: 5.6s to complete
#     error(train)=5.64e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 27: 5.9s to complete
#     error(train)=5.31e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 28: 5.8s to complete
#     error(train)=4.85e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 29: 6.9s to complete
#     error(train)=4.51e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 30: 5.3s to complete
#     error(train)=4.13e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 31: 5.4s to complete
#     error(train)=3.91e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 32: 5.1s to complete
#     error(train)=3.65e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 33: 5.0s to complete
#     error(train)=3.56e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 34: 6.2s to complete
#     error(train)=3.24e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 35: 5.5s to complete
#     error(train)=3.13e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 36: 5.3s to complete
#     error(train)=2.95e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 37: 6.1s to complete
#     error(train)=2.82e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 38: 5.7s to complete
#     error(train)=2.68e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 39: 4.1s to complete
#     error(train)=2.57e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 40: 4.4s to complete
#     error(train)=2.45e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 41: 4.6s to complete
#     error(train)=2.36e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 42: 4.1s to complete
#     error(train)=2.29e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 43: 4.1s to complete
#     error(train)=2.19e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 44: 4.4s to complete
#     error(train)=2.12e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 45: 4.6s to complete
#     error(train)=2.05e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 46: 4.6s to complete
#     error(train)=1.97e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 47: 4.7s to complete
#     error(train)=1.91e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 48: 4.2s to complete
#     error(train)=1.85e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 49: 4.9s to complete
#     error(train)=1.80e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 50: 4.3s to complete
#     error(train)=1.73e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 51: 4.3s to complete
#     error(train)=1.68e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 52: 4.6s to complete
#     error(train)=1.63e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 53: 4.4s to complete
#     error(train)=1.58e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 54: 4.6s to complete
#     error(train)=1.55e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 55: 5.8s to complete
#     error(train)=1.51e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 56: 4.8s to complete
#     error(train)=1.46e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 57: 5.2s to complete
#     error(train)=1.43e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 58: 4.8s to complete
#     error(train)=1.39e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 59: 4.4s to complete
#     error(train)=1.35e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 60: 5.1s to complete
#     error(train)=1.32e-04, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 61: 4.2s to complete
#     error(train)=1.29e-04, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 62: 4.5s to complete
#     error(train)=1.26e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 63: 5.9s to complete
#     error(train)=1.23e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 64: 5.2s to complete
#     error(train)=1.20e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 65: 5.5s to complete
#     error(train)=1.18e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 66: 4.8s to complete
#     error(train)=1.15e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 67: 5.2s to complete
#     error(train)=1.13e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 68: 4.2s to complete
#     error(train)=1.11e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 69: 4.6s to complete
#     error(train)=1.08e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 70: 4.2s to complete
#     error(train)=1.06e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 71: 4.3s to complete
#     error(train)=1.04e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 72: 4.4s to complete
#     error(train)=1.02e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 73: 6.0s to complete
#     error(train)=9.98e-05, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 74: 3.9s to complete
#     error(train)=9.81e-05, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 75: 4.7s to complete
#     error(train)=9.59e-05, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 76: 5.8s to complete
#     error(train)=9.43e-05, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 77: 4.7s to complete
#     error(train)=9.25e-05, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 78: 4.7s to complete
#     error(train)=9.10e-05, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 79: 5.1s to complete
#     error(train)=8.95e-05, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 80: 5.2s to complete
#     error(train)=8.81e-05, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 81: 4.2s to complete
#     error(train)=8.63e-05, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 82: 4.5s to complete
#     error(train)=8.48e-05, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 83: 4.6s to complete
#     error(train)=8.36e-05, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 84: 4.6s to complete
#     error(train)=8.21e-05, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 85: 5.2s to complete
#     error(train)=8.07e-05, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 86: 4.3s to complete
#     error(train)=7.95e-05, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 87: 4.7s to complete
#     error(train)=7.82e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 88: 4.3s to complete
#     error(train)=7.70e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 89: 5.0s to complete
#     error(train)=7.57e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 90: 4.8s to complete
#     error(train)=7.48e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 91: 4.2s to complete
#     error(train)=7.36e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 92: 5.7s to complete
#     error(train)=7.24e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 93: 4.7s to complete
#     error(train)=7.14e-05, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 94: 4.7s to complete
#     error(train)=7.05e-05, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 95: 5.0s to complete
#     error(train)=6.93e-05, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 96: 6.4s to complete
#     error(train)=6.84e-05, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 97: 4.8s to complete
#     error(train)=6.75e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 98: 4.8s to complete
#     error(train)=6.65e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 99: 3.7s to complete
#     error(train)=6.56e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Epoch 100: 4.2s to complete
#     error(train)=6.47e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
